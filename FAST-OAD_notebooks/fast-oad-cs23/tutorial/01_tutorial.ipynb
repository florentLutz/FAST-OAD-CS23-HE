# %% [markdown]
# <div class="row">
#   <div class="column">
#     <img src="./img/logo-onera.png" width="200">
#   </div>
#   <div class="column">
#     <img src="./img/logo-ISAE_SUPAERO.png" width="200">
#   </div>
# </div>

# %% [markdown]
# # FAST-OAD-GA Tutorial

# %% [markdown]
# FAST-OAD-GA is an add-on package for [FAST-OAD framework](https://github.com/fast-aircraft-design/FAST-OAD) for performing rapid Overall Aircraft Design in the category General Aviation (GA). The computational core of FAST-OAD being based on the  [OpenMDAO framework](https://openmdao.org/).

# %%
import warnings

warnings.filterwarnings(action="ignore")

# %% [markdown]
# ## 1. Setting up and analyzing the initial problem

# %% [markdown]
# To organize our work, we propose to use two user folders `data/` and `workdir/`. For instance, in `data/` we store a XML file which describes the Beechcraft Duchess. In `workdir/`, we store files generated or modified by FAST-OAD.

# %%
import os.path as pth
from fastoad import api as api_cs25
import logging
import shutil

from IPython.core.display import display, HTML

# Define relative path
DATA_FOLDER_PATH = "data"
WORK_FOLDER_PATH = "workdir"

# Remove work folder
shutil.rmtree(WORK_FOLDER_PATH, ignore_errors=True)

# Define files
CONFIGURATION_FILE = pth.join(WORK_FOLDER_PATH, "oad_process.yml")
SOURCE_FILE = pth.join(DATA_FOLDER_PATH, "beechcraft_76.xml")

# For having log messages on screen
logging.basicConfig(level=logging.INFO, format="%(levelname)-8s: %(message)s")

# For using all screen width
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# After defining a configuration file name, we can ask FAST-GA to generate a default configuration file based on the default OAD model implemented in the framework:

# %%
api_cs25.generate_configuration_file(
    CONFIGURATION_FILE,
    overwrite=True,
    distribution_name="fast-oad-cs23",
    sample_file_name="fastga.yml",
)
# Out:
# WindowsPath('C:/Users/a.carotenuto/Documents/GitHub/FAST-OAD-CS23-HE/FAST-OAD_notebooks/fast-oad-cs23/tutorial/workdir/oad_process.yml')

# %% [markdown]
# You can now checkout the generated [configuration file](./workdir/oad_process.yml). In this configuration file, we have specified an input file name 'problem_inputs.xml'. We can ask FAST-OAD to generate the inputs of the default model with the CeRAS parameters as default values:

# %%
api_cs25.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE, overwrite=True)
# Out:
# 'C:/Users/a.carotenuto/Documents/GitHub/FAST-OAD-CS23-HE/FAST-OAD_notebooks/fast-oad-cs23/tutorial/workdir/problem_inputs.xml'

# %% [markdown]
# You can now checkout the generated [input file](./workdir/problem_inputs.xml). As shown previously in the user file architecture, the values in this file can be modified by the user and will be considered by FAST-OAD when executing a computational process.

# %% [markdown]
# A useful feature that FAST-OAD provides is to list the outputs of the model defined in the configuration file:

# %%
api_cs25.list_variables(CONFIGURATION_FILE)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>NAME</th>
#       <th>I/O</th>
#       <th>DESCRIPTION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>data:TLAR:NPAX_design</td>
#       <td>IN</td>
#       <td>design number of passengers (two pilots are included de facto, meaning for a 2 seater, NPAX_design is equal to 0)</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:luggage_mass_design</td>
#       <td>IN</td>
#       <td>luggage design mass</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:range</td>
#       <td>IN</td>
#       <td>design range</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:v_approach</td>
#       <td>IN</td>
#       <td>approach speed</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:v_cruise</td>
#       <td>IN</td>
#       <td>cruise speed</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:v_max_sl</td>
#       <td>IN</td>
#       <td>maximum speed at sea level</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:cooling:cruise:CD0</td>
#       <td>IN</td>
#       <td>profile drag due to cooling in cruise conditions</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:cooling:low_speed:CD0</td>
#       <td>IN</td>
#       <td>profile drag due to cooling in low speed conditions</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:propeller:mach</td>
#       <td>IN</td>
#       <td>mach number used to compute the polar of the airfoil used in the propeller computation</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:propeller:reynolds</td>
#       <td>IN</td>
#       <td>reynolds number used to compute the polar of the airfoil used in the propeller computation</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:vertical_tail:efficiency</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:aisle_width</td>
#       <td>IN</td>
#       <td>width of the aisle</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:luggage:mass_max</td>
#       <td>IN</td>
#       <td>maximum luggage mass</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:passenger:NPAX_max</td>
#       <td>IN</td>
#       <td>maximum number of passengers in the aircraft</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:passenger:count_by_row</td>
#       <td>IN</td>
#       <td>number of passenger seats per row</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:passenger:length</td>
#       <td>IN</td>
#       <td>passenger seats length</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:passenger:width</td>
#       <td>IN</td>
#       <td>width of passenger seats</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:pilot:length</td>
#       <td>IN</td>
#       <td>pilot seats length</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:pilot:width</td>
#       <td>IN</td>
#       <td>width of pilot seats</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap:chord_ratio</td>
#       <td>IN</td>
#       <td>flap chord as a percentage of the wing chord</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap:span_ratio</td>
#       <td>IN</td>
#       <td>flap span as a percentage of the wing span</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap_type</td>
#       <td>IN</td>
#       <td>flap type (0.0 - plain flap, 2.0 - single slotted flap, 3.0 - split flap)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:has_T_tail</td>
#       <td>IN</td>
#       <td>0=horizontal tail is attached to fuselage / 1=horizontal tail is attached to top of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:MAC:at25percent:x:from_wingMAC25</td>
#       <td>IN</td>
#       <td>distance along X between 25% MAC of wing and 25% MAC of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:aspect_ratio</td>
#       <td>IN</td>
#       <td>horizontal tail aspect ratio</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:elevator_chord_ratio</td>
#       <td>IN</td>
#       <td>elevator chord ratio</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:thickness_ratio</td>
#       <td>IN</td>
#       <td>thickness ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:landing_gear:type</td>
#       <td>IN</td>
#       <td>0=non-retractable / 1=retractable</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:average_rpm</td>
#       <td>IN</td>
#       <td>average rotation speed of the propeller</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:blades_number</td>
#       <td>IN</td>
#       <td>number of blades on the propeller</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:chord_vect</td>
#       <td>IN</td>
#       <td>blade chord at the station along the radius stored in radius_ratio_vect</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:depth</td>
#       <td>IN</td>
#       <td>depth of the propeller</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:diameter</td>
#       <td>IN</td>
#       <td>propeller diameter</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:hub_diameter</td>
#       <td>IN</td>
#       <td>propeller hub diameter</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:radius_ratio_vect</td>
#       <td>IN</td>
#       <td>blade station at which blade geometric properties are sampled, as a percent of blade radius</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:sweep_vect</td>
#       <td>IN</td>
#       <td>blade sweep at the station along the radius stored in radius_ratio_vect</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propeller:twist_vect</td>
#       <td>IN</td>
#       <td>blade twist at the station along the radius stored in radius_ratio_vect</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:count</td>
#       <td>IN</td>
#       <td>number of engine</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:layout</td>
#       <td>IN</td>
#       <td>position of engines (1=under the wing / 2=rear fuselage / 3=nose)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:y_ratio</td>
#       <td>IN</td>
#       <td>engine position along wing span (if layout=1-2)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:aspect_ratio</td>
#       <td>IN</td>
#       <td>vertical tail aspect ratio</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:max_thickness:x_ratio</td>
#       <td>IN</td>
#       <td>position of the point of maximum thickness as a ratio of vertical tail chord</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:rudder:chord_ratio</td>
#       <td>IN</td>
#       <td>flap rudder as a percentage of the wing chord</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:rudder:max_deflection</td>
#       <td>IN</td>
#       <td>rudder maximum deflection</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:thickness_ratio</td>
#       <td>IN</td>
#       <td>thickness ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:aspect_ratio</td>
#       <td>IN</td>
#       <td>wing aspect ratio</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:dihedral</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:kink:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (Y-position of kink)/(semi-span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of wing</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of wing</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:thickness_r

# %% [markdown]
# Another useful feature is to list the modules of the model defined in the configuration file:

# %%
api_cs25.list_modules(CONFIGURATION_FILE)
# Out:
# <table>
# <tbody>
# <tr><td>AVAILABLE MODULE IDENTIFIERS                     </td><td>MODULE PATH                                                                                                                                                                     </td></tr>
# <tr><td>fastga.aerodynamics.cl_cd_polar                  </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\compute_polar.py                                               </td></tr>
# <tr><td>fastga.aerodynamics.highspeed.legacy             </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\aerodynamics_high_speed.py                                     </td></tr>
# <tr><td>fastga.aerodynamics.legacy                       </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\aerodynamics.py                                                </td></tr>
# <tr><td>fastga.aerodynamics.load_factor                  </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\load_factor.py                                                 </td></tr>
# <tr><td>fastga.aerodynamics.lowspeed.legacy              </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\aerodynamics_low_speed.py                                      </td></tr>
# <tr><td>fastga.aerodynamics.propeller                    </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\external\propeller_code\compute_propeller_aero.py              </td></tr>
# <tr><td>fastga.aerodynamics.propeller.coeff_map          </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\external\propeller_code\compute_propeller_coefficient_map.py   </td></tr>
# <tr><td>fastga.aerodynamics.stability_derivatives.legacy </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\aerodynamics\aerodynamics_stability_derivatives.py                          </td></tr>
# <tr><td>fastga.geometry.alternate                        </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\geometry\geometry.py                                                        </td></tr>
# <tr><td>fastga.geometry.legacy                           </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\geometry\geometry.py                                                        </td></tr>
# <tr><td>fastga.handling_qualities.all_handling_qualities </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\handling_qualities\handling_qualities.py                                    </td></tr>
# <tr><td>fastga.handling_qualities.static_margin          </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\handling_qualities\compute_static_margin.py                                 </td></tr>
# <tr><td>fastga.handling_qualities.tail_sizing            </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\handling_qualities\tail_sizing\update_tail_areas.py                         </td></tr>
# <tr><td>fastga.loads.wing                                </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\load_analysis\wing\loads.py                                                 </td></tr>
# <tr><td>fastga.loop.mtow                                 </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\weight\mass_breakdown\update_mtow.py                                        </td></tr>
# <tr><td>fastga.loop.wing_area                            </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\loops\update_wing_area_group.py                                             </td></tr>
# <tr><td>fastga.loop.wing_position                        </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\loops\update_wing_position.py                                               </td></tr>
# <tr><td>fastga.performances.mission                      </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\performances\mission\mission.py                                             </td></tr>
# <tr><td>fastga.performances.mission_builder_prep         </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\performances\mission\mission_builder_prep.py                                </td></tr>
# <tr><td>fastga.performances.mission_vector               </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\performances\mission_vector\full_mission.py                                 </td></tr>
# <tr><td>fastga.performances.payload_range                </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\performances\payload_range\payload_range.py                                 </td></tr>
# <tr><td>fastga.propulsion.turboprop_construction         </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\propulsion\fuel_propulsion\basicTurbo_prop_map\basicTP_engine_constructor.py</td></tr>
# <tr><td>fastga.weight.legacy                             </td><td>C:\Users\a.carotenuto\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\models\weight\weight.py                                                            </td></tr>
# <tr><td>fastga_he.environmental.energy_simple            </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\environmental_impacts\simple_energy_impact.py                                                      </td></tr>
# <tr><td>fastga_he.geometry.aspect_ratio_fixed_span       </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\geometry\aspect_ratio_fixed_span.py                                                                </td></tr>
# <tr><td>fastga_he.lca.legacy                             </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\environmental_impacts\lca.py                                                                       </td></tr>
# <tr><td>fastga_he.loads.wing                             </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\load_analysis\wing\loads.py                                                                        </td></tr>
# <tr><td>fastga_he.loop.wing_area                         </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\loops\update_wing_area_group.py                                                                    </td></tr>
# <tr><td>fastga_he.payload_range.inner                    </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\performances\payload_range\payload_range_inner_group.py                                            </td></tr>
# <tr><td>fastga_he.payload_range.outer                    </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\models\performances\payload_range\payload_range.py                                                        </td></tr>
# <tr><td>fastga_he.performances.mission_vector            </td><td>C:\Users\a.carotenuto\Documents\GitHub\FAST-OAD-CS23-HE\src\fastga_he\model

# %% [markdown]
# Another useful feature is the [N2 diagram](http://openmdao.org/twodocs/versions/latest/basic_guide/make_n2.html) visualization available in OpenMDAO to see the structure of the model:

# %%
from IPython.display import IFrame

N2_FILE = pth.join(WORK_FOLDER_PATH, "n2.html")
api_cs25.write_n2(CONFIGURATION_FILE, N2_FILE, overwrite=True)

IFrame(src=N2_FILE, width="100%", height="500px")
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="workdir\n2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Alternatively, you can create a [WhatsOpt](https://github.com/OneraHub/WhatsOpt-Doc#whatsopt-documentation) account to generate the XDSM of the problem. If your account is created, you may uncomment next lines and run them (this should take ~ 1 min):

# %%
from IPython.display import IFrame

XDSM_FILE = pth.join(WORK_FOLDER_PATH, "xdsm.html")
api_cs25.write_xdsm(CONFIGURATION_FILE, XDSM_FILE, overwrite=True)

IFrame(src=XDSM_FILE, width="100%", height="500px")
# Out:
# Analysis FASTOADModel pushed
#         <iframe
#             width="100%"
#             height="500px"
#             src="workdir\xdsm.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. Running your first MDA

# %% [markdown]
# ### Beechcraft
# Here we run an MDA, that is solving the multidisciplinary couplings using the different nested solvers in the model, without running the optimization problem even if it is defined in the configuration file.

# %%
eval_problem = api_cs25.evaluate_problem(CONFIGURATION_FILE, overwrite=True)
# Out:
# ===============
# aircraft_sizing
# ===============
# NL: NLBGS 1 ; 12528315.4 1
# NL: NLBGS 2 ; 2145771.65 0.171273757
# NL: NLBGS 3 ; 1078331.97 0.0860715852
# NL: NLBGS 4 ; 465041.595 0.0371192439
# NL: NLBGS 5 ; 96149.0867 0.0076745423
# NL: NLBGS 6 ; 65390.6008 0.00521942485
# NL: NLBGS 7 ; 32378.2808 0.00258440817
# NL: NLBGS 8 ; 12130.2671 0.000968228101
# NL: NLBGS Converged

# %% [markdown]
# Let's save these results. We will use them in the next workbook, that shows some post-processing utilities.

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")
Beechcraft_OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs_Beechcraft_800nm_mda.xml")
shutil.copy(OUTPUT_FILE, Beechcraft_OUTPUT_FILE)
# Out:
# 'workdir\\problem_outputs_Beechcraft_800nm_mda.xml'

# %% [markdown]
# The `variable-viewer` provides a way to inspect the content of the XML file. The dropdown lists above the table allow to filter the displayed variable.

# %%
api_cs25.variable_viewer(OUTPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# In particular, you may inspect the `data:handling_qualities:static_margin` variable.
# You will see that its value is equal to the value we set as the target meaning the MDA process converged correctly.

# %% [markdown]
# ### Beechcraft for 1000 nm range
# Here we run an MDA but we change one of the Top Level Aircraft Requirement (TLAR): the range. We choose a 1000 nm range instead of 800 nm for the Beechcraft. For that we use the `VariableViewer` tool on the input file to change the range (do not forget to save!). Just like this:
# ![variable_viewer](./img/variable_viewer_change_range.gif)

# %%
INPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_inputs.xml")
api_cs25.variable_viewer(INPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# Now that the range has been changed, we run again the MDA.

# %%
eval_problem = api_cs25.evaluate_problem(CONFIGURATION_FILE, overwrite=True)
# Out:
# ===============
# aircraft_sizing
# ===============
# NL: NLBGS 1 ; 12528315.4 1
# NL: NLBGS 2 ; 2145771.65 0.171273757
# NL: NLBGS 3 ; 1078331.97 0.0860715852
# NL: NLBGS 4 ; 465041.595 0.0371192439
# NL: NLBGS 5 ; 96149.0867 0.0076745423
# NL: NLBGS 6 ; 65390.6008 0.00521942485
# NL: NLBGS 7 ; 32378.2808 0.00258440817
# NL: NLBGS 8 ; 12130.2671 0.000968228101
# NL: NLBGS Converged

# %% [markdown]
# Let's save again these new results, for post-processing them in next notebook.

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")
Beechcraft_1000nm_OUTPUT_FILE = pth.join(
    WORK_FOLDER_PATH, "problem_outputs_Beechcraft_1000nm_mda.xml"
)
shutil.copy(OUTPUT_FILE, Beechcraft_1000nm_OUTPUT_FILE)
# Out:
# 'workdir\\problem_outputs_Beechcraft_1000nm_mda.xml'

# %% [markdown]
# ## 3. Running your first MDO
#
# ## Beechcraft 800 nm optimization
#
# As seen earlier, the current aircraft configuration is estimated with a fixed distance between the wing aerodynamic center and the horizontal tail aerodynamic center. We will unlock this parameter using a simple optimization problem that will move horizontal tail position in order to minimize the mission consumption.
#
# The default configuration file defines this optimization problem that aims at:
# - minimizing the fuel consumption for the mission (objective),
# - with respect to the distance between the wing and the tail aerodynamic center (design variables): by extension the horizontal tail to wing distance,
# - subject to no additional constraint.
#
# However, running the MDO with the propeller performance estimation will take a very long time. Consequently, and since the propeller won't change from one MDO loop to another, we decided to use a different .yml file for the probleme definition and reuse the propeller performance map computed in the MDA's hence why the input file will be the output file of a previous MDA.
#
# *(This run should take approximately 20 minutes)*

# %%
CONFIGURATION_FILE_MDO = pth.join(WORK_FOLDER_PATH, "oad_process_mdo.yml")
SOURCE_FILE_MDO = pth.join(WORK_FOLDER_PATH, "problem_outputs_Beechcraft_800nm_mda.xml")
shutil.copy(pth.join(DATA_FOLDER_PATH, "fastga_mdo.yml"), CONFIGURATION_FILE_MDO)
# Out:
# 'workdir\\oad_process_mdo.yml'

# %%
# Set back the inputs from the reference Beechcraft 800 nm
api_cs25.generate_inputs(CONFIGURATION_FILE_MDO, SOURCE_FILE_MDO, overwrite=True)
# Out:
# 'C:/Users/a.carotenuto/Documents/GitHub/FAST-OAD-CS23-HE/FAST-OAD_notebooks/fast-oad-cs23/tutorial/workdir/problem_inputs.xml'

# %% [markdown]
# To visualize and edit the optimization problem definition (present in the configuration file .toml) you can use the `optimization_viewer` tool. If design variables or constraints have active bounds they are yellow whereas they are red if they are violated. Modifiying the `Initial Value` will modify the input file defined in the configuration file .toml whereas `Value` corresponds to the value found in the output file defined in the configuration file (here it is the 800 nm MDA run).

# %%
api_cs25.optimization_viewer(CONFIGURATION_FILE_MDO)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %%
optim_problem = api_cs25.optimize_problem(CONFIGURATION_FILE_MDO, overwrite=True)
# Out:
# NL: NLBGS 1 ; 12528315.4 1
# NL: NLBGS 2 ; 2145771.65 0.171273757
# NL: NLBGS 3 ; 1078331.97 0.0860715852
# NL: NLBGS 4 ; 465041.595 0.0371192439
# NL: NLBGS 5 ; 96149.0867 0.0076745423
# NL: NLBGS 6 ; 65394.4437 0.00521973158
# NL: NLBGS 7 ; 89855.4282 0.00717218757
# NL: NLBGS 8 ; 11347.9006 0.000905780241
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8407.42646 1
# NL: NLBGS 2 ; 2589.38995 0.307988415
# NL: NLBGS 3 ; 969.233243 0.115282988
# NL: NLBGS 4 ; 676.867816 0.0805083244
# NL: NLBGS 5 ; 315.027803 0.0374701825
# NL: NLBGS 6 ; 195.384896 0.0232395606
# NL: NLBGS 7 ; 121.283027 0.0144257018
# NL: NLBGS 8 ; 68.9457977 0.00820058291
# NL: NLBGS 9 ; 39.2561695 0.00466922544
# NL: NLBGS 10 ; 21.9513433 0.00261094681
# NL: NLBGS 11 ; 12.0167599 0.00142930301
# NL: NLBGS 12 ; 6.51205692 0.000774560082
# NL: NLBGS Converged
# NL: NLBGS 1 ; 219.440127 1
# NL: NLBGS 2 ; 698642.078 3183.74806
# NL: NLBGS 3 ; 65918.699 300.394918
# NL: NLBGS 4 ; 131272.436 598.215275
# NL: NLBGS 5 ; 26034.7385 118.641649
# NL: NLBGS 6 ; 16514.998 75.2596994
# NL: NLBGS 7 ; 11625.754 52.9791618
# NL: NLBGS 8 ; 5601.93352 25.5283006
# NL: NLBGS 9 ; 2985.26646 13.6040135
# NL: NLBGS 10 ; 1622.55955 7.39408774
# NL: NLBGS 11 ; 830.0872 3.78275027
# NL: NLBGS 12 ; 424.158144 1.93291059
# NL: NLBGS 13 ; 215.873467 0.983746545
# NL: NLBGS 14 ; 108.072266 0.492490904
# NL: NLBGS 15 ; 53.7529249 0.244954857
# NL: NLBGS 16 ; 26.5205801 0.120855654
# NL: NLBGS 17 ; 12.9580264 0.0590503962
# NL: NLBGS 18 ; 6.24615677 0.0284640592
# NL: NLBGS 19 ; 3.0996403 0.014125221
# NL: NLBGS 20 ; 1.42782436 0.0065066694
# NL: NLBGS 21 ; 0.623404096 0.00284088468
# NL: NLBGS 22 ; 0.340139352 0.00155003261
# NL: NLBGS 23 ; 0.168043309 0.000765782043
# NL: NLBGS Converged
# NL: NLBGS 1 ; 296.854199 1
# NL: NLBGS 2 ; 524615.501 1767.24972
# NL: NLBGS 3 ; 61923.2165 208.598082
# NL: NLBGS 4 ; 124133.055 418.161695
# NL: NLBGS 5 ; 27715.3994 93.3636764
# NL: NLBGS 6 ; 16994.1668 57.2475203
# NL: NLBGS 7 ; 10501.6659 35.3765113
# NL: NLBGS 8 ; 5173.2543 17.4269197
# NL: NLBGS 9 ; 3290.06104 11.0830874
# NL: NLBGS 10 ; 2501.51345 8.42674098
# NL: NLBGS 11 ; 1107.08231 3.72938066
# NL: NLBGS 12 ; 561.151164 1.89032584
# NL: NLBGS 13 ; 304.369028 1.02531488
# NL: NLBGS 14 ; 155.504937 0.523842808
# NL: NLBGS 15 ; 76.0835765 0.256299479
# NL: NLBGS 16 ; 37.9623849 0.127882257
# NL: NLBGS 17 ; 18.6533447 0.0628367218
# NL: NLBGS 18 ; 9.03918962 0.0304499301
# NL: NLBGS 19 ; 4.27487669 0.0144005936
# NL: NLBGS 20 ; 2.05968839 0.00693838388
# NL: NLBGS 21 ; 1.03255926 0.00347833805
# NL: NLBGS 22 ; 0.545390917 0.00183723498
# NL: NLBGS 23 ; 0.211268032 0.000711689553
# NL: NLBGS Converged
# NL: NLBGS 1 ; 159.001598 1
# NL: NLBGS 2 ; 247265.274 1555.11188
# NL: NLBGS 3 ; 31071.2159 195.414489
# NL: NLBGS 4 ; 60712.797 381.837654
# NL: NLBGS 5 ; 15911.5575 100.071683
# NL: NLBGS 6 ; 9396.12307 59.0945198
# NL: NLBGS 7 ; 6090.9235 38.30731
# NL: NLBGS 8 ; 2988.90323 18.7979446
# NL: NLBGS 9 ; 1557.70924 9.79681502
# NL: NLBGS 10 ; 816.200402 5.13328427
# NL: NLBGS 11 ; 409.333165 2.57439655
# NL: NLBGS 12 ; 216.77208 1.36333271
# NL: NLBGS 13 ; 632.049222 3.9751124
# NL: NLBGS 14 ; 38.3106279 0.240944924
# NL: NLBGS 15 ; 76.5568742 0.481484937
# NL: NLBGS 16 ; 19.2229401 0.12089778
# NL: NLBGS 17 ; 12.2124172 0.0768068835
# NL: NLBGS 18 ; 8.12405775 0.0510941894
# NL: NLBGS 19 ; 4.15652331 0.0261413933
# NL: NLBGS 20 ; 2.18283479 0.0137283828
# NL: NLBGS 21 ; 1.38274769 0.00869643897
# NL: NLBGS 22 ; 0.573513827 0.00360696895
# NL: NLBGS 23 ; 0.347934101 0.00218824279
# NL: NLBGS 24 ; 0.190543854 0.00119837698
# NL: NLBGS 25 ; 0.093744276 0.000589580717
# NL: NLBGS Converged
# NL: NLBGS 1 ; 200.061806 1
# NL: NLBGS 2 ; 439621.656 2197.4292
# NL: NLBGS 3 ; 46574.3198 232.799657
# NL: NLBGS 4 ; 92472.6649 462.220483
# NL: NLBGS 5 ; 20726.4506 103.600237
# NL: NLBGS 6 ; 13434.1294 67.1498955
# NL: NLBGS 7 ; 9267.92037 46.3252859
# NL: NLBGS 8 ; 4548.48662 22.7354071
# NL: NLBGS 9 ; 2436.92067 12.1808391
# NL: NLBGS 10 ; 1323.63572 6.61613398
# NL: NLBGS 11 ; 682.699445 3.41244267
# NL: NLBGS 12 ; 351.238181 1.75564835
# NL: NLBGS 13 ; 179.863073 0.899037532
# NL: NLBGS 14 ; 90.7601965 0.453660787
# NL: NLBGS 15 ; 45.4766814 0.22731316
# NL: NLBGS 16 ; 22.6077795 0.113003976
# NL: NLBGS 17 ; 11.1341533 0.0556535678
# NL: NLBGS 18 ; 5.43082716 0.0271457469
# NL: NLBGS 19 ; 2.74280757 0.0137098011
# NL: NLBGS 20 ; 1.22970201 0.00614661054
# NL: NLBGS 21 ; 0.681201892 0.00340495722
# NL: NLBGS 22 ; 0.23224705 0.0011608765
# NL: NLBGS 23 ; 0.139649758 0.000698033076
# NL: NLBGS Converged
# NL: NLBGS 1 ; 87.8146558 1
# NL: NLBGS 2 ; 215072.289 2449.16168
# NL: NLBGS 3 ; 22048.1589 251.076072
# NL: NLBGS 4 ; 43942.5298 500.400866
# NL: NLBGS 5 ; 9824.54741 111.87822
# NL: NLBGS 6 ; 6089.80618 69.3484035
# NL: NLBGS 7 ; 4148.7844 47.2447834
# NL: NLBGS 8 ; 2019.98942 23.0028735
# NL: NLBGS 9 ; 1068.57647 12.1685436
# NL: NLBGS 10 ; 573.318994 6.5287393
# NL: NLBGS 11 ; 292.616464 3.33220533
# NL: NLBGS 12 ; 148.717398 1.69353733
# NL: NLBGS 13 ; 75.206645 0.856424754
# NL: NLBGS 14 ; 37.4620294 0.426603385
# NL: NLBGS 15 ; 18.4916163 0.210575515
# NL: NLBGS 16 ; 9.09843696 0.10360955
# NL: NLBGS 17 ; 4.42481844 0.0503881544
# NL: NLBGS 18 ; 2.05533909 0.0234054221
# NL: NLBGS 19 ; 1.04531093 0.0119036045
# NL: NLBGS 20 ; 0.554781693 0.00631764354
# NL: NLBGS 21 ; 0.182908864 0.00208289679
# NL: NLBGS 22 ; 0.106143934 0.00120872687
# NL: NLBGS 23 ; 0.0587522251 0.00066904806
# NL: NLBGS Converged
# NL: NLBGS 1 ; 51.385114 1
# NL: NLBGS 2 ; 120868.863 2352.21552
# NL: NLBGS 3 ; 12460.3032 242.488578
# NL: NLBGS 4 ; 24861.1106 483.819313
# NL: NLBGS 5 ; 5520.24363 107.428848
# NL: NLBGS 6 ; 3508.89299 68.286177
# NL: NLBGS 7 ; 2412.88874 46.95696
# NL: NLBGS 8 ; 1175.81017 22.8823113
# NL: NLBGS 9 ; 626.369349 12.1897044
# NL: NLBGS 10 ; 338.414306 6.58584323
# NL: NLBGS 11 ; 175.123207 3.40805329
# NL: NLBGS 12 ; 2459.6981 47.8679118
# NL: NLBGS 13 ; 95.9581699 1.86743129
# NL: NLBGS 14 ; 384.996221 7.49236872
# NL: NLBGS 15 ; 95.3087356 1.85479272
# NL: NLBGS 16 ; 61.1945566 1.19090047
# NL: NLBGS 17 ; 43.2017877 0.840745194
# NL: NLBGS 18 ; 22.2316815 0.432648286
# NL: NLBGS 19 ; 12.0004591 0.233539603
# NL: NLBGS 20 ; 6.60458025 0.128531003
# NL: NLBGS 21 ; 3.51649756 0.0684341686
# NL: NLBGS 22 ; 1.7485279 0.0340279073
# NL: NLBGS 23 ; 0.921617888 0.0179355034
# NL: NLBGS 24 ; 0.468902769 0.00912526473
# NL: NLBGS 25 ; 0.249300433 0.00485160805
# NL: NLBGS 26 ; 0.124264633 0.00241830022
# NL: NLBGS 27 ; 0.0878307603 0.00170926468
# NL: NLBGS 28 ; 0.146253031 0.00284621401
# NL: NLBGS 29 ; 0.0953984025 0.00185653772
# NL: NLBGS 30 ; 0.116781558 0.00227267293
# NL: NLBGS 31 ; 0.105814176 0.00205923793
# NL: NLBGS 32 ; 0.111396208 0.00216786923
# NL: NLBGS 33 ; 0.108687815 0.0021151615
# NL: NLBGS 34 ; 0.109987217 0.00214044902
# NL: NLBGS 35 ; 0.109411519 0.00212924542
# NL: NLBGS 36 ; 6.66563381 0.12971916
# NL: NLBGS 37 ; 5.0669786 0.098607908
# NL: NLBGS 38 ; 2.59512512 0.0505034419
# NL: NLBGS 39 ; 1.72968291 0.033661167
# NL: NLBGS 40 ; 0.71682641 0.0139500792
# NL: NLBGS 41 ; 0.512000312 0.00996398124
# NL: NLBGS 42 ; 0.297611017 0.00579177497
# NL: NLBGS 43 ; 0.154652048 0.00300966634
# NL: NLBGS 44 ; 0.0827038103 0.00160948967
# NL: NLBGS 45 ; 0.0435517426 0.000847555627
# NL: NLBGS Converged
# NL: NLBGS 1 ; 24.4809928 1
# NL: NLBGS 2 ; 62755.3594 2563.43196
# NL: NLBGS 3 ; 6289.11025 256.89768
# NL: NLBGS 4 ; 12549.6518 512.628387
# NL: NLBGS 5 ; 2675.59701 109.292831
# NL: NLBGS 6 ; 1735.43532 70.8890909
# NL: NLBGS 7 ; 1207.21446 49.3123162
# NL: NLBGS 8 ; 589.539876 24.0815346
# NL: NLBGS 9 ; 315.680249 12.894912
# NL: NLBGS 10 ; 171.471142 7.00425606
# NL: NLBGS 11 ; 88.4164015 3.61163463
# NL: NLBGS 12 ; 45.3764517 1.85353805
# NL: NLBGS 13 ; 23.2471554 0.94960019
# NL: NLBGS 14 ; 11.7156212 0.47855989
# NL: NLBGS 15 ; 5.92406713 0.241986392
# NL: NLBGS 16 ; 2.86645263 0.117088905
# NL: NLBGS 17 ; 1.43630318 0.0586701363
# NL: NLBGS 18 ; 0.72025728 0.0294210813
# NL: NLBGS 19 ; 0.363453096 0.0148463381
# NL: NLBGS 20 ; 0.176430939 0.00720685392
# NL: NLBGS 21 ; 0.0855416332 0.00349420605
# NL: NLBGS 22 ; 0.0413815841 0.00169035563
# NL: NLBGS 23 ; 0.0198078204 0.000809110175
# NL: NLBGS Converged
# Optimization Complete
# -----------------------------------

# %% [markdown]
# Let's save these results:

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")
CeRAS_OPT_OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs_Beechcraft_800nm_mdo.xml")
shutil.copy(OUTPUT_FILE, CeRAS_OPT_OUTPUT_FILE)
# Out:
# 'workdir\\problem_outputs_Beechcraft_800nm_mdo.xml'

# %% [markdown]
# The `optimizer_viewer` offers a convenient summary of the optimization result:

# %%
api_cs25.optimization_viewer(CONFIGURATION_FILE_MDO)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 api_cs25.optimization_viewer(CONFIGURATION_FILE_MDO)
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\cmd\api.py:766, in optimization_viewer(configuration_file_path)
#     759 def optimization_viewer(configuration_file_path: Union[str, PathLike]):
#     760     """
#     761     Displays optimization information and enables its editing
#     762
#     763     :param configuration_file_path: problem definition
#     764     :return: display of the OptimizationViewer
#     765     """
# --> 766     conf = FASTOADProblemConfigurator(configuration_file_path)
#     767     conf._set_configuration_modifier(_PROBLEM_CONFIGURATOR)
#     768     viewer = OptimizationViewer()
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\configuration\configuration.py:84, in FASTOADProblemConfigurator.__init__(self, conf_file_path)
#      82 self._conf_file_path: Optional[Path] = None
#      83 if conf_file_path:
# ---> 84     self.load(conf_file_path)
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\configuration\configuration.py:167, in FASTOADProblemConfigurator.load(self, conf_file)
#     165 else:
#     166     self._serializer = _YAMLSerializer()
# --> 167 self._serializer.read(self._conf_file_path)
#     169 # Syntax validation
#     170 with PackageReader(resources).open_text(JSON_SCHEMA_NAME) as json_file:
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\configuration\configuration.py:659, in _YAMLSerializer.read(self, file_path)
#     657 def read(self, file_path: Union[str, PathLike]):
#     658     yaml = YAML(typ="safe")
# --> 659     with open(file_path) as yaml_file:
#     660         self._data = yaml.load(yaml_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\a.carotenuto\\Documents\\GitHub\\FAST-OAD-CS23-HE\\FAST-OAD_notebooks\\fast-oad-cs23\\tutorial\\workdir\\oad_process_mdo.yml'

# %% [markdown]
# You can use the `VariableViewer` tool to see the optimization results for all variables of the system by loading the .xml output file:

# %%
RESULT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")
api_cs25.variable_viewer(RESULT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…
