# %% [markdown]
# <div class="row">
#   <div class="column">
#     <img src="./img/logo-onera.png" width="200">
#   </div>
#   <div class="column">
#     <img src="./img/logo-ISAE_SUPAERO.png" width="200">
#   </div>
# </div>

# %% [markdown]
# # FAST-OAD Postprocessing Tutorial
# FAST-OAD is a framework for performing rapid Overall Aircraft Design. The computational core of FAST-OAD is based on the  [OpenMDAO framework](https://openmdao.org/).
#
#
#
# This notebook will show you the basic postprocessing features that FAST-OAD offers.
#
# **Note: The 01_tutorial notebook has to be ran to generate the results files used in this postprocessing notebook**
#
# *Tip: hover your mouse pointer over any plot to inspect it or get menu to manipulate it*

# %%
import os.path as pth

import fastoad.api as oad
import fastga.utils.postprocessing.analysis_and_plots as api_plots

# For using all screen width
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# C:\Users\a.carotenuto\AppData\Local\Temp\ipykernel_4764\983720038.py:7: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# To illustrate the set of postprocessing plots we will use the three designs obtained in the `01_tutorial` notebook:
# - Beechcraft 800 nm Multidisciplinary Design Analysis (MDA)
# - Beechcraft 1000 nm Multidisciplinary Design Analysis (MDA)
# - Beechcraft 800 nm Multidisciplinary Design Optimization (MDO)

# %%
DATA_FOLDER_PATH = "data"
WORK_FOLDER_PATH = "workdir"

Beechcraft_800nm_MDA_OUTPUT_FILE = pth.join(
    WORK_FOLDER_PATH, "problem_outputs_Beechcraft_800nm_mda.xml"
)
Beechcraft_1000nm_MDA_OUTPUT_FILE = pth.join(
    WORK_FOLDER_PATH, "problem_outputs_Beechcraft_1000nm_mda.xml"
)
Beechcraft_800nm_MDO_OUTPUT_FILE = pth.join(
    WORK_FOLDER_PATH, "problem_outputs_Beechcraft_800nm_mdo.xml"
)

# %% [markdown]
# ## 1. Introduction
#
# The general philosophy of the postprocessing plots is to use the result data file as the source information. Hence, offline of the computational process. Furthermore, the idea is to compare design results by enabling the superposition of different plots for the postprocessing plots where comparison is relevant.

# %% [markdown]
# ## 2. Geometry plots
# For instance here, we use the `fig` variable generated by the code line 1 and plot the result of line 2 on the existing figure. There is no number of maximum superpositions.

# %%
fig = oad.wing_geometry_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, name="Beechcraft 800 nm MDA")
fig = oad.wing_geometry_plot(
    Beechcraft_1000nm_MDA_OUTPUT_FILE, name="Beechcraft 1000 nm MDA", fig=fig
)
fig = oad.wing_geometry_plot(
    Beechcraft_800nm_MDO_OUTPUT_FILE, name="Beechcraft 800 nm MDO", fig=fig
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FastError                                 Traceback (most recent call last)
# FastError:
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 fig = oad.wing_geometry_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, name="Beechcraft 800 nm MDA")
#       2 fig = oad.wing_geometry_plot(
#       3     Beechcraft_1000nm_MDA_OUTPUT_FILE, name="Beechcraft 1000 nm MDA", fig=fig
#       4 )
#       5 fig = oad.wing_geometry_plot(
#       6     Beechcraft_800nm_MDO_OUTPUT_FILE, name="Beechcraft 800 nm MDO", fig=fig
#       7 )
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\gui\analysis_and_plots.py:48, in wing_geometry_plot(aircraft_file_path, name, fig, file_formatter)
#      33 def wing_geometry_plot(
#      34     aircraft_file_path: Union[str, PathLike], name=None, fig=None, *, file_formatter=None
#      35 ) -> go.FigureWidget:
#      36     """
#      37     Returns a figure plot of the top view of the wing.
#      38     Different designs can be superposed by providing an existing fig.
#    (...)
#      46     :return: wing plot figure
#      47     """
# ---> 48     variables = VariableIO(aircraft_file_path, file_formatter).read()
#      50     wing_kink_leading_edge_x = variables["data:geometry:wing:kink:leading_edge:x:local"].value[0]
#      51     wing_tip_leading_edge_x = variables["data:geometry:wing:tip:leading_edge:x:local"].value[0]
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\variable_io.py:72, in VariableIO.read(self, only, ignore)
#      60 """
#      61 Reads variables from provided data source.
#      62
#    (...)
#      69 :return: a VariableList instance where outputs have been defined using provided source.
#      70 """
#      71 if isinstance(self.data_source, Path) and not self.data_source.is_file():
# ---> 72     raise FileNotFoundError(
#      73         f'File "{self.data_source}" is unavailable for reading.'
#      74     ) from FastError()
#      76 variables = self.formatter.read_variables(self.data_source)
#      77 used_variables = self._filter_variables(variables, only=only, ignore=ignore)
#
# FileNotFoundError: File "workdir\problem_outputs_Beechcraft_800nm_mda.xml" is unavailable for reading.

# %%
fig = oad.aircraft_geometry_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, name="Beechcraft 800 nm MDA")
fig = oad.aircraft_geometry_plot(
    Beechcraft_1000nm_MDA_OUTPUT_FILE, name="Beechcraft 1000 nm MDA", fig=fig
)
fig = oad.aircraft_geometry_plot(
    Beechcraft_800nm_MDO_OUTPUT_FILE, name="Beechcraft 800 nm MDO", fig=fig
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FastError                                 Traceback (most recent call last)
# FastError:
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 fig = oad.aircraft_geometry_plot(
#       2     Beechcraft_800nm_MDA_OUTPUT_FILE, name="Beechcraft 800 nm MDA"
#       3 )
#       4 fig = oad.aircraft_geometry_plot(
#       5     Beechcraft_1000nm_MDA_OUTPUT_FILE, name="Beechcraft 1000 nm MDA", fig=fig
#       6 )
#       7 fig = oad.aircraft_geometry_plot(
#       8     Beechcraft_800nm_MDO_OUTPUT_FILE, name="Beechcraft 800 nm MDO", fig=fig
#       9 )
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\gui\analysis_and_plots.py:120, in aircraft_geometry_plot(aircraft_file_path, name, fig, file_formatter)
#     105 def aircraft_geometry_plot(
#     106     aircraft_file_path: Union[str, PathLike], name=None, fig=None, *, file_formatter=None
#     107 ) -> go.FigureWidget:
#     108     """
#     109     Returns a figure plot of the top view of the wing.
#     110     Different designs can be superposed by providing an existing fig.
#    (...)
#     118     :return: wing plot figure
#     119     """
# --> 120     variables = VariableIO(aircraft_file_path, file_formatter).read()
#     122     # Wing parameters
#     123     wing_kink_leading_edge_x = variables["data:geometry:wing:kink:leading_edge:x:local"].value[0]
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\variable_io.py:72, in VariableIO.read(self, only, ignore)
#      60 """
#      61 Reads variables from provided data source.
#      62
#    (...)
#      69 :return: a VariableList instance where outputs have been defined using provided source.
#      70 """
#      71 if isinstance(self.data_source, Path) and not self.data_source.is_file():
# ---> 72     raise FileNotFoundError(
#      73         f'File "{self.data_source}" is unavailable for reading.'
#      74     ) from FastError()
#      76 variables = self.formatter.read_variables(self.data_source)
#      77 used_variables = self._filter_variables(variables, only=only, ignore=ignore)
#
# FileNotFoundError: File "workdir\problem_outputs_Beechcraft_800nm_mda.xml" is unavailable for reading.

# %% [markdown]
# ## 3. Mass breakdown plots

# %% [markdown]
# This first mass breakdown plot enables to visualize the Maximum TakeOff Weight (MTOW) and Overall Weight Empty (OWE) for a single design.

# %%
fig = api_plots.mass_breakdown_sun_plot(Beechcraft_800nm_MDA_OUTPUT_FILE)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FastError                                 Traceback (most recent call last)
# FastError:
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 fig = api_plots.mass_breakdown_sun_plot(Beechcraft_800nm_MDA_OUTPUT_FILE)
#       2 fig.show()
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\utils\postprocessing\analysis_and_plots.py:847, in mass_breakdown_sun_plot(aircraft_file_path, file_formatter)
#     837 def mass_breakdown_sun_plot(aircraft_file_path: str, file_formatter=None):
#     838     """
#     839     Returns a figure sunburst plot of the mass breakdown.
#     840     On the left a MTOW sunburst and on the right a OWE sunburst.
#    (...)
#     845     :return: sunburst plot figure.
#     846     """
# --> 847     variables = VariableIO(aircraft_file_path, file_formatter).read()
#     849     var_names_and_new_units = {
#     850         "data:weight:aircraft:MTOW": "kg",
#     851         "data:weight:aircraft:OWE": "kg",
#     852         "data:weight:aircraft:payload": "kg",
#     853         "data:mission:sizing:fuel": "kg",
#     854     }
#     856     # pylint: disable=unbalanced-tuple-unpacking # It is balanced for the parameters provided
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\variable_io.py:72, in VariableIO.read(self, only, ignore)
#      60 """
#      61 Reads variables from provided data source.
#      62
#    (...)
#      69 :return: a VariableList instance where outputs have been defined using provided source.
#      70 """
#      71 if isinstance(self.data_source, Path) and not self.data_source.is_file():
# ---> 72     raise FileNotFoundError(
#      73         f'File "{self.data_source}" is unavailable for reading.'
#      74     ) from FastError()
#      76 variables = self.formatter.read_variables(self.data_source)
#      77 used_variables = self._filter_variables(variables, only=only, ignore=ignore)
#
# FileNotFoundError: File "workdir\problem_outputs_Beechcraft_800nm_mda.xml" is unavailable for reading.

# %% [markdown]
# This second mass breakdown plot provides less detail but enables to compare designs.

# %% [markdown]
# ## 4. Mission plots

# %%
fig = api_plots.mass_breakdown_bar_plot(
    Beechcraft_800nm_MDA_OUTPUT_FILE, name="Beechcraft 800 nm MDA"
)
fig = api_plots.mass_breakdown_bar_plot(
    Beechcraft_1000nm_MDA_OUTPUT_FILE, name="Beechcraft 1000 nm MDA", fig=fig
)
fig = api_plots.mass_breakdown_bar_plot(
    Beechcraft_800nm_MDO_OUTPUT_FILE, name="Beechcraft 800 nm MDO", fig=fig
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FastError                                 Traceback (most recent call last)
# FastError:
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 fig = api_plots.mass_breakdown_bar_plot(
#       2     Beechcraft_800nm_MDA_OUTPUT_FILE, name="Beechcraft 800 nm MDA"
#       3 )
#       4 fig = api_plots.mass_breakdown_bar_plot(
#       5     Beechcraft_1000nm_MDA_OUTPUT_FILE, name="Beechcraft 1000 nm MDA", fig=fig
#       6 )
#       7 fig = api_plots.mass_breakdown_bar_plot(
#       8     Beechcraft_800nm_MDO_OUTPUT_FILE, name="Beechcraft 800 nm MDO", fig=fig
#       9 )
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastga\utils\postprocessing\analysis_and_plots.py:792, in mass_breakdown_bar_plot(aircraft_file_path, name, fig, file_formatter)
#     777 def mass_breakdown_bar_plot(
#     778     aircraft_file_path: str, name=None, fig=None, file_formatter=None
#     779 ) -> go.FigureWidget:
#     780     """
#     781     Returns a figure plot of the aircraft mass breakdown using bar plots.
#     782     Different designs can be superposed by providing an existing fig.
#    (...)
#     790     :return: bar plot figure.
#     791     """
# --> 792     variables = VariableIO(aircraft_file_path, file_formatter).read()
#     794     var_names_and_new_units = {
#     795         "data:weight:aircraft:MTOW": "kg",
#     796         "data:weight:aircraft:OWE": "kg",
#     797         "data:weight:aircraft:payload": "kg",
#     798         "data:mission:sizing:fuel": "kg",
#     799     }
#     801     # pylint: disable=unbalanced-tuple-unpacking # It is balanced for the parameters provided
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\site-packages\fastoad\io\variable_io.py:72, in VariableIO.read(self, only, ignore)
#      60 """
#      61 Reads variables from provided data source.
#      62
#    (...)
#      69 :return: a VariableList instance where outputs have been defined using provided source.
#      70 """
#      71 if isinstance(self.data_source, Path) and not self.data_source.is_file():
# ---> 72     raise FileNotFoundError(
#      73         f'File "{self.data_source}" is unavailable for reading.'
#      74     ) from FastError()
#      76 variables = self.formatter.read_variables(self.data_source)
#      77 used_variables = self._filter_variables(variables, only=only, ignore=ignore)
#
# FileNotFoundError: File "workdir\problem_outputs_Beechcraft_800nm_mda.xml" is unavailable for reading.

# %% [markdown]
# An other post-processing tool is available: the mission viewer. You simply add the mission files that interest you:

# %%
Beechcraft_800nm_MDA_MISSION_FILE = pth.join(WORK_FOLDER_PATH, "workdir/mda_mission_results.csv")

mission = oad.MissionViewer()
mission.add_mission(Beechcraft_800nm_MDA_MISSION_FILE, name="Beechracft 800 nm MDA")

mission.missions["Beechracft 800 nm MDA"]
# Out:
#          time [s]  altitude [m]  isa_offset [K]  ground_distance [m]  \
# 0        0.000000  1.524000e+01             0.0         0.000000e+00
# 1        4.776000  4.547662e+01             0.0         2.204876e+02
# 2        9.552000  7.553272e+01             0.0         4.413244e+02
# 3       14.328000  1.054094e+02             0.0         6.625088e+02
# 4       19.104000  1.351077e+02             0.0         8.840393e+02
# 5       23.880000  1.646287e+02             0.0         1.105914e+03
# 6       28.656000  1.939735e+02             0.0         1.328132e+03
# 7       33.432000  2.231430e+02             0.0         1.550690e+03
# 8       38.208000  2.521385e+02             0.0         1.773588e+03
# 9       42.984000  2.809608e+02             0.0         1.996825e+03
# 10      47.760000  3.096111e+02             0.0         2.220397e+03
# 11      52.536000  3.380903e+02             0.0         2.444304e+03
# 12      57.312000  3.663995e+02             0.0         2.668545e+03
# 13      62.088000  3.945397e+02             0.0         2.893117e+03
# 14      66.864000  4.225119e+02             0.0         3.118019e+03
# 15      71.640000  4.503171e+02             0.0         3.343250e+03
# 16      76.416000  4.779563e+02             0.0         3.568807e+03
# 17      81.192000  5.054305e+02             0.0         3.794691e+03
# 18      85.968000  5.327407e+02             0.0         4.020898e+03
# 19      90.744000  5.598878e+02             0.0         4.247427e+03
# 20      95.520000  5.868729e+02             0.0         4.474277e+03
# 21     100.296000  6.136969e+02             0.0         4.701447e+03
# 22     105.072000  6.403607e+02             0.0         4.928934e+03
# 23     109.848000  6.668653e+02             0.0         5.156738e+03
# 128  1694.365824                 0.0            53.249342
# 129  1694.297457                 0.0            53.287321
# 130  1694.229226                 0.0            53.325112
# 131  1694.161130                 0.0            53.362716
# 132  1694.093167                 0.0            53.400135
# 133  1694.025337                 0.0            53.437367
# 134  1693.957638                 0.0            53.474415
# 135  1693.890070                 0.0            53.511278
# 136  1693.822630                 0.0            53.547959
# 137  1693.755318                 0.0            53.584456
# 138  1693.688133                 0.0            53.620771
# 139  1693.621073                 0.0            53.656905
# 140  1693.554138                 0.0            53.692858
# 141  1693.487327                 0.0            53.728632
# 142  1693.420637                 0.0            53.764226
# 143  1693.354069                 0.0            53.799642
# 144  1693.287621                 0.0            53.834880
# 145  1693.221293                 0.0            53.869940
# 146  1693.155082                 0.0            53.904825
# 147  1693.088989                 0.0            53.939533
# 148  1693.023011                 0.0            53.974067
# 149  1692.957149                 0.0            54.008426
# 150  1692.891401                 0.0            54.042612
# 151  1692.825766                 0.0            54.076625
# 152  1692.760243                 0.0            54.110465
# 153  1692.726038                 0.0            81.282222
# 154  1690.967554                 0.0            81.282222
# 155  1689.209635                 0.0            81.282222
# 156  1687.452280                 0.0            81.282222
# 157  1685.695488                 0.0            81.282222
# 158  1683.939259                 0.0            81.282222
# 159  1682.183592                 0.0            81.282222
# 160  1680.428484                 0.0            81.282222
# 161  1678.673937                 0.0            81.282222
# 162  1676.919948                 0.0            81.282222
# 163  1675.166516                 0.0            81.282222
# 164  1673.413642                 0.0            81.282222
# 165  1671.661323                 0.0            81.282222
# 166  1669.909559                 0.0            81.282222
# 167  1668.158349                 0.0            81.282222
# 168  1666.407692                 0.0            81.282222
# 169  1664.657587                 0.0            81.282222
# 170  1662.908034                 0.0            81.282222
# 171  1661.159030                 0.0            81.282222
# 172  1659.410577                 0.0            81.282222
# 173  1657.662671                 0.0            81.282222
# 174  1655.915313                 0.0            81.282222
# 175  1654.168502                 0.0            81.282222
# 176  1652.422236                 0.0            81.282222
# 177  1650.676515                 0.0            81.282222
# 178  1648.931339                 0.0            81.282222
# 179  1647.186705                 0.0            81.282222
# 180  1645.442613                 0.0            81.282222
# 181  1643.699062                 0.0            81.282222
# 182  1641.956052                 0.0            81.282222
# 183  1640.213581                 0.0            81.282222
# 184  1638.471649                 0.0            81.282222
# 185  1636.730254                 0.0            81.282222
# 186  1634.989396                 0.0            81.282222
# 187  1633.249074                 0.0            81.282222
# 188  1631.509286                 0.0            81.282222
# 189  1629.770033                 0.0            81.282222
# 190  1628.031313                 0.0            81.282222
# 191  1626.293125                 0.0            81.282222
# 192  1624.555469                 0.0            81.282222
# 193  1622.818343                 0.0            81.282222
# 194  1621.081746                 0.0            81.282222
# 195  1619.345679                 0.0            81.282222
# 196  1617.610139                 0.0            81.282222
# 197  1615.875126                 0.0            81.282222
# 198  1614.140640                 0.0            81.282222
# 199  1612.406679                 0.0            81.282222
# 200  1610.673242                 0.0            81.282222
# 201  1608.940328                 0.0            81.282222
# 202  1607.207938                 0.0            81.282222
# 203  1605.476069                 0.0            81.282222
# 204  1603.744721                 0.0            81.282222
# 205  1602.013893                 0.0            81.282222
# 283  1512.034612                 0.0            58.210645
# 284  1511.739334                 0.0            58.037482
# 285  1511.444769                 0.0            57.865065
# 286  1511.150915                 0.0            57.693391
# 287  1510.857768                 0.0            57.522455
# 288  1510.565324                 0.0            57.352254
# 289  1510.273581                 0.0            57.182783
# 290  1509.982533                 0.0            57.014038
# 291  1509.692179                 0.0            56.846016
# 292  1509.402513                 0.0            56.678712
# 293  1509.113533                 0.0            56.512122
# 294  1508.825233                 0.0            56.346243
# 295  1508.537610                 0.0            56.181070
# 296  1508.250660                 0.0            56.016600
# 297  1507.964378                 0.0            55.852828
# 298  1507.678760                 0.0            55.689752
# 299  1507.393803                 0.0            55.527367
# 300  1507.109501                 0.0            55.365669
# 301  1506.825849                 0.0            55.204654
# 302  1506.542845                 0.0            55.044320
# 303  1506.260482                 0.0            54.884661
#
#      equivalent_airspeed [m/s]  mach [-]  engine_setting [None]  ...  \
# 0                    46.563735  0.136957                      2  ...
# 1                    46.563345  0.137202                      2  ...
# 2                    46.562956  0.137446                      2  ...
# 3                    46.562567  0.137689                      2  ...
# 4                    46.562179  0.137931                      2  ...
# 5                    46.561792  0.138172                      2  ...
# 6                    46.561405  0.138412                      2  ...
# 7                    46.561019  0.138652                      2  ...
# 8                    46.560634  0.138891                      2  ...
# 9                    46.560250  0.139128                      2  ...
# 10                   46.559866  0.139365                      2  ...
# 11                   46.559483  0.139601                      2  ...
# 12                   46.559101  0.139837                      2  ...
# 13                   46.558720  0.140071                      2  ...
# 14                   46.558339  0.140304                      2  ...
# 15                   46.557959  0.140537                      2  ...
# 16                   46.557580  0.140769                      2  ...
# 17                   46.557202  0.141000                      2  ...
# 18                   46.556825  0.141230                      2  ...
# 19                   46.556448  0.141459                      2  ...
# 20                   46.556072  0.141687                      2  ...
# 21                   46.555697  0.141915                      2  ...
# 22                   46.555323  0.142141                      2  ...
# 23                   46.554950  0.142367                      2  ...
# 24                   46.554577  0.142592                      2  ...
# 25                   46.554205  0.142816                      2  ...
# 26                   46.553835  0.143039                      2  ...
# 27                   46.553465  0.143261                      2  ...
# 28                   46.553096  0.143483                      2  ...
# 29                   46.552727  0.143703                      2  ...
# 30                   46.552360  0.143923                      2  ...
# 31                   46.551994  0.144142                      2  ...
# 32                   46.551628  0.144360                      2  ...
# 33                   46.551263  0.144577                      2  ...
# 34                   46.550899  0.144793                      2  ...
# 35                   46.550537  0.145009                      2  ...
# 36                   46.550175  0.145223                      2  ...
# 37                   46.549813  0.145437                      2  ...
# 38                   46.549453  0.145650                      2  ...
# 39                   46.549094  0.145862                      2  ...
# 40                   46.548735  0.146073                      2  ...
# 41                   46.548378  0.146283                      2  ...
# 42                   46.548021  0.146493                      2  ...
# 43                   46.547666  0.146702                      2  ...
# 44                   46.547311  0.146909                      2  ...
# 45                   46.546957  0.147116                      2  ...
# 46                   46.546605  0.147323                      2  ...
# 47                   46.546253  0.147528                      2  ...
# 48                   46.545902  0.147732                      2  ...
# 49                   46.545552  0.147936                      2  ...
# 50                   46.545203  0.148139                      2  ...
# 51                   46.544855  0.148341                      2  ...
# 52                   46.544508  0.148542                      2  ...
# 53                   46.544162  0.148742                      2  ...
# 54                   46.543817  0.148942                      2  ...
# 55                   46.543473  0.149140                      2  ...
# 56                   46.543129  0.149338                      2  ...
# 57                   46.542787  0.149535                      2  ...
# 58                   46.542446  0.149731                      2  ...
# 59                   46.542106  0.149927                      2  ...
# 60                   46.541767  0.150121                      2  ...
# 61                   46.541428  0.150315                      2  ...
# 62                   46.541091  0.150508                      2  ...
# 63                   46.540755  0.150700                      2  ...
# 64                   46.540420  0.150891                      2  ...
# 65                   46.540086  0.151082                      2  ...
# 66                   46.539752  0.151272                      2  ...
# 67                   46.539420  0.151460                      2  ...
# 68                   46.539089  0.151648                      2  ...
# 69                   46.538759  0.151836                      2  ...
# 70                   46.538429  0.152022                      2  ...
# 71                   46.538101  0.152208                      2  ...
# 72                   46.537774  0.152393                      2  ...
# 73                   46.537448  0.152577                      2  ...
# 74                   46.537123  0.152760                      2  ...
# 75                   46.536799  0.152942                      2  ...
# 76                   46.536476  0.153124                      2  ...
# 77                   46.536154  0.153305                      2  ...
# 78                   46.535833  0.153485                      2  ...
# 79                   46.535513  0.153664                      2  ...
# 80                   46.535194  0.153843                      2  ...
# 81                   46.534876  0.154020                      2  ...
# 82                   46.534559  0.154197                      2  ...
# 83                   46.534244  0.154374                      2  ...
# 84                   46.533929  0.154549                      2  ...
# 85                   46.533615  0.154723                      2  ...
# 86                   46.533302  0.154897                      2  ...
# 87                   46.532991  0.155070                      2  ...
# 88                   46.532680  0.155243                      2  ...
# 89                   46.532371  0.155414                      2  ...
# 90                   46.532062  0.155585                      2  ...
# 91                   46.531755  0.155755                      2  ...
# 92                   46.531448  0.155924                      2  ...
# 93                   46.531143  0.156093                      2  ...
# 94                   46.530839  0.156260                      2  ...
# 95                   46.530535  0.156427                      2  ...
# 96                   46.530233  0.156593                      2  ...
# 97                   46.529932  0.156759                      2  ...
# 98                   46.529632  0.156924                      2  ...
# 99                   46.529333  0.157088                      2  ...
# ...
# 273     6.068531                             NaN  sizing:main_route:descent
# 274     6.067047                             NaN  sizing:main_route:descent
# 275     6.065569                             NaN  sizing:main_route:descent
# 276     6.064098                             NaN  sizing:main_route:descent
# 277     6.062632                             NaN  sizing:main_route:descent
# 278     6.061173                             NaN  sizing:main_route:descent
# 279     6.059720                             NaN  sizing:main_route:descent
# 280     6.058272                             NaN  sizing:main_route:descent
# 281     6.056831                             NaN  sizing:main_route:descent
# 282     6.055395                             NaN  sizing:main_route:descent
# 283     6.053966                             NaN  sizing:main_route:descent
# 284     6.052542                             NaN  sizing:main_route:descent
# 285     6.051123                             NaN  sizing:main_route:descent
# 286     6.049711                             NaN  sizing:main_route:descent
# 287     6.048304                             NaN  sizing:main_route:descent
# 288     6.046903                             NaN  sizing:main_route:descent
# 289     6.045507                             NaN  sizing:main_route:descent
# 290     6.044117                             NaN  sizing:main_route:descent
# 291     6.042732                             NaN  sizing:main_route:descent
# 292     6.041353                             NaN  sizing:main_route:descent
# 293     6.039979                             NaN  sizing:main_route:descent
# 294     6.038610                             NaN  sizing:main_route:descent
# 295     6.037247                             NaN  sizing:main_route:descent
# 296     6.035889                             NaN  sizing:main_route:descent
# 297     6.034536                             NaN  sizing:main_route:descent
# 298     6.033189                             NaN  sizing:main_route:descent
# 299     6.031846                             NaN  sizing:main_route:descent
# 300     6.030509                             NaN  sizing:main_route:descent
# 301     6.029176                             NaN  sizing:main_route:descent
# 302     6.027849                             NaN  sizing:main_route:descent
# 303     6.026527                             NaN  sizing:main_route:descent
#
#      gamma [rad]  CL_wing [-]  CL_htp [-]
# 0       0.136285     0.757531    0.017828
# 1       0.135270     0.757727    0.017829
# 2       0.134263     0.757921    0.017831
# 3       0.133265     0.758112    0.017832
# 4       0.132276     0.758302    0.017834
# 5       0.131295     0.758488    0.017835
# 6       0.130322     0.758673    0.017836
# 7       0.129357     0.758855    0.017838
# 8       0.128401     0.759035    0.017839
# 9       0.127453     0.759213    0.017840
# 10      0.126513     0.759388    0.017841
# 11      0.125580     0.759562    0.017842
# 12      0.124656     0.759733    0.017843
# 13      0.123740     0.759902    0.017844
# 14      0.122831     0.760069    0.017845
# 15      0.121929     0.760234    0.017846
# 16      0.121036     0.760397    0.017847
# 17      0.120149     0.760558    0.017848
# 18      0.119271     0.760717    0.017849
# 19      0.118399     0.760874    0.017850
# 20      0.117535     0.761029    0.017851
# 21      0.116678     0.761183    0.017852
# 22      0.115828     0.761334    0.017852
# 23      0.114985     0.761484    0.017853
# 24      0.114149     0.761631    0.017854
# 25      0.113320     0.761777    0.017854
# 26      0.112498     0.761921    0.017855
# 27      0.111683     0.762064    0.017856
# 28      0.110874     0.762205    0.017856
# 29      0.110072     0.762344    0.017857
# 30      0.109277     0.762481    0.017857
# 31      0.108488     0.762617    0.017858
# 32      0.107705     0.762751    0.017858
# 33      0.106929     0.762883    0.017859
# 34      0.106159     0.763014    0.017859
# 35      0.105396     0.763144    0.017859
# 36      0.104639     0.763271    0.017860
# 37      0.103888     0.763398    0.017860
# 38      0.103143     0.763522    0.017860
# 39      0.102404     0.763646    0.017861
# 40      0.101671     0.763767    0.017861
# 41      0.100944     0.763888    0.017861
# 42      0.100223     0.764007    0.017861
# 43      0.099508     0.764124    0.017862
# 44      0.098798     0.764240    0.017862
# 45      0.098094     0.764355    0.017862
# 46      0.097396     0.764468    0.017862
# 47      0.096703     0.764580    0.017862
# 48      0.096016     0.764691    0.017862
# 49      0.095335     0.764800    0.017862
# 50      0.094659     0.764908    0.017862
# 51      0.093988     0.765015    0.017863
# 52      0.093322     0.765120    0.017863
# 53      0.092662     0.765224    0.017863
# 54      0.092008     0.765327    0.017862
# 55      0.091358     0.765429    0.017862
# 56      0.090713     0.765530    0.017862
# 57      0.090074     0.765629    0.017862
# 58      0.089440     0.765727    0.017862
# 59      0.088810     0.765824    0.017862
# 60      0.088186     0.765920    0.017862
# 61      0.087567     0.766015    0.017862
# 62      0.086952     0.766109    0.017862
# 63      0.086342     0.766201    0.017861
# 64      0.085737     0.766293    0.017861
# 65      0.085137     0.766383    0.017861
# 66      0.084542     0.766472    0.017861
# 67      0.083951     0.766561    0.017861
# 231     0.000000     0.323258    0.003300
# 232     0.000000     0.322921    0.003277
# 233     0.000000     0.322584    0.003255
# 234     0.000000     0.322247    0.003233
# 235     0.000000     0.321910    0.003211
# 236     0.000000     0.321573    0.003188
# 237     0.000000     0.321237    0.003166
# 238     0.000000     0.320900    0.003144
# 239     0.000000     0.320564    0.003121
# 240     0.000000     0.320227    0.003099
# 241     0.000000     0.319891    0.003077
# 242     0.000000     0.319555    0.003055
# 243     0.000000     0.319219    0.003032
# 244     0.000000     0.318883    0.003010
# 245     0.000000     0.318547    0.002988
# 246     0.000000     0.318211    0.002966
# 247     0.000000     0.317876    0.002943
# 248     0.000000     0.317540    0.002921
# 249     0.000000     0.317205    0.002899
# 250     0.000000     0.316869    0.002877
# 251     0.000000     0.316534    0.002855
# 252     0.000000     0.316199    0.002832
# 253     0.000000     0.316199    0.002832
# 253    -0.023899     0.510665    0.007831
# 254    -0.023973     0.510531    0.007824
# 255    -0.024048     0.510397    0.007816
# 256    -0.024122     0.510264    0.007808
# 257    -0.024197     0.510131    0.007801
# 258    -0.024272     0.509999    0.007793
# 259    -0.024347     0.509867    0.007785
# 260    -0.024422     0.509736    0.007778
# 261    -0.024497     0.509606    0.007770
# 262    -0.024572     0.509476    0.007763
# 263    -0.024648     0.509347    0.007755
# 264    -0.024723     0.509218    0.007748
# 265    -0.024799     0.509090    0.007741
# 266    -0.024875     0.508962    0.007733
# 267    -0.024951     0.508835    0.007726
# 268    -0.025027     0.508708    0.007718
# 269    -0.025103     0.508582    0.007711
# 270    -0.025180     0.508457    0.007704
# 271    -0.025256     0.508332    0.007697
# 272    -0.025333     0.508207    0.007689
# 273    -0.025409     0.508084    0.007682
# 274    -0.025486     0.507960    0.007675
# 275    -0.025563     0.507837    0.007668
# 276    -0.025640     0.507715    0.007661
# 277    -0.025718     0.507593    0.007653
# 278    -0.025795     0.507471    0.007646
# 279    -0.025872     0.507351    0.007639
# 280    -0.025950     0.507230    0.007632
# 281    -0.026028     0.507110    0.007625
# 282    -0.026106     0.506991    0.007618
# 283    -0.026184     0.506872    0.007611
# 284    -0.026262     0.506754    0.007604
# 285    -0.026340     0.506636    0.007597
# 286    -0.026419     0.506518    0.007590
# 287    -0.026497     0.506401    0.007583
# 288    -0.026576     0.506284    0.007576
# 289    -0.026655     0.506168    0.007569
# 290    -0.026733     0.506053    0.007563
# 291    -0.026812     0.505938    0.007556
# 292    -0.026892     0.505823    0.007549
# 293    -0.026971     0.505709    0.007542
# 294    -0.027050     0.505595    0.007535
# 295    -0.027130     0.505481    0.007529
# 296    -0.027210     0.505368    0.007522
# 297    -0.027289     0.505256    0.007515
# 298    -0.027369     0.505144    0.007508
# 299    -0.027449     0.505032    0.007502
# 300    -0.027530     0.504921    0.007495
# 301    -0.027610     0.504810    0.007489
# 302    -0.027690     0.504700    0.007482
# 303    -0.027771     0.504590    0.007475
#
# [305 rows x 24 columns]

# %% [markdown]
# Or you can plot the missions:

# %%
mission.display()
# Out:
# HBox(children=(Label(value='x:'), Dropdown(index=3, options=('time [s]', 'altitude [m]', 'isa_offset [K]', 'gr…
# Output()

# %% [markdown]
# ## 5. Payload-Range Diagram

# %% [markdown]
# FAST-OAD-GA also allows the user to display some interresting plot from an engineering point of view. One such example is the payload-range diagram. Such diagram, though useful for assessing the performances of the aircraft, are not mandatory for the MDA to converge, so they are not included in the base configuration file. This also means that before plotting the diagram we will have to run a special simulation on the file obtained at the output of the MDA before being able to display the actual plot
#
# As we did in the first tutorial, let's set up a run with only the module that computes the payload range diagram (it can take up to 10 min).

# %%
import shutil

CONFIGURATION_FILE_DATA = pth.join(DATA_FOLDER_PATH, "payload_range.yml")
CONFIGURATION_FILE = pth.join(WORK_FOLDER_PATH, "payload_range.yml")

SOURCE_FILE_PAYLOAD_RANGE = pth.join(WORK_FOLDER_PATH, "payload_range.xml")

# First copy the configuration file inside the workfolder, and create a duplicate of the MDA outputs

shutil.copy(CONFIGURATION_FILE_DATA, CONFIGURATION_FILE)
shutil.copy(Beechcraft_800nm_MDA_OUTPUT_FILE, SOURCE_FILE_PAYLOAD_RANGE)

# Then generate the inputs

oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE_PAYLOAD_RANGE, overwrite=True)

eval_problem = oad.evaluate_problem(CONFIGURATION_FILE, overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 11
#       8 # First copy the configuration file inside the workfolder, and create a duplicate of the MDA outputs
#      10 shutil.copy(CONFIGURATION_FILE_DATA, CONFIGURATION_FILE)
# ---> 11 shutil.copy(Beechcraft_800nm_MDA_OUTPUT_FILE, SOURCE_FILE_PAYLOAD_RANGE)
#      13 # Then generate the inputs
#      15 oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE_PAYLOAD_RANGE, overwrite=True)
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\shutil.py:417, in copy(src, dst, follow_symlinks)
#     415 if os.path.isdir(dst):
#     416     dst = os.path.join(dst, os.path.basename(src))
# --> 417 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File ~\AppData\Local\anaconda3\envs\FAST-OAD-CS23-HE\lib\shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
#     256             with open(dst, 'wb') as fdst:
#     257                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'workdir\\problem_outputs_Beechcraft_800nm_mda.xml'

# %% [markdown]
# We will now save the outputs and use the proper post-processing function

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "payload_range_outputs.xml")

fig = oad.payload_range(OUTPUT_FILE, name="Beechcraft 800 nm MDA")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "payload_range_outputs.xml")
# ----> 3 fig =oad.payload_range(OUTPUT_FILE, name="Beechcraft 800 nm MDA")
#       4 fig.show()
#
# AttributeError: module 'fastoad.api' has no attribute 'payload_range'

# %% [markdown]
# ## 6. Aircraft polars

# %% [markdown]
# Another diagram that we can plot is the aircraft polars (be they equilibrated or not equilibrated). As for the payload-range we first need to launch the analysis before plotting them. This time, it should only take a couple seconds.

# %%
import shutil

CONFIGURATION_FILE_DATA = pth.join(DATA_FOLDER_PATH, "aircraft_polar.yml")
CONFIGURATION_FILE = pth.join(WORK_FOLDER_PATH, "aircraft_polar.yml")

SOURCE_FILE_POLAR = pth.join(WORK_FOLDER_PATH, "polar_inputs.xml")

# First copy the configuration file inside the workfolder, and create a duplicate of the MDA outputs

shutil.copy(CONFIGURATION_FILE_DATA, CONFIGURATION_FILE)
shutil.copy(Beechcraft_800nm_MDA_OUTPUT_FILE, SOURCE_FILE_POLAR)

# Then generate the inputs

oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE_POLAR, overwrite=True)

eval_problem = oad.evaluate_problem(CONFIGURATION_FILE, overwrite=True)

# %% [markdown]
# As before we will now save the outputs and use the proper post-processing function as before. Let's start with the non equilibrated one.

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "polar_outputs.xml")

fig = oad.aircraft_polar(OUTPUT_FILE, name="Beechcraft 800 nm MDA")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "polar_outputs.xml")
# ----> 3 fig = oad.aircraft_polar(OUTPUT_FILE, name="Beechcraft 800 nm MDA")
#       4 fig.show()
#
# AttributeError: module 'fastoad.api' has no attribute 'aircraft_polar'

# %% [markdown]
# And let's now do the equilibrated one.

# %%
fig = oad.aircraft_polar(OUTPUT_FILE, name="Beechcraft 800 nm MDA", equilibrated=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 fig = oad.aircraft_polar(OUTPUT_FILE, name="Beechcraft 800 nm MDA", equilibrated=True)
#       2 fig.show()
#
# AttributeError: module 'fastoad.api' has no attribute 'aircraft_polar'

# %% [markdown]
# ## 7. Propeller performances map

# %% [markdown]
# It is also possible to display the efficiency maps computed and used in FAST-OAD-CS23. At sea level, it is done like so:

# %%
fig = oad.propeller_efficiency_map_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, sea_level=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 fig = oad.propeller_efficiency_map_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, sea_level=True)
#       2 fig.show()
#
# AttributeError: module 'fastoad.api' has no attribute 'propeller_efficiency_map_plot'

# %% [markdown]
# For cruise level, we just need to set the sea_level parameter to `False`

# %%
fig = oad.propeller_efficiency_map_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, sea_level=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 fig = oad.propeller_efficiency_map_plot(Beechcraft_800nm_MDA_OUTPUT_FILE, sea_level=False)
#       2 fig.show()
#
# AttributeError: module 'fastoad.api' has no attribute 'propeller_efficiency_map_plot'

# %% [markdown]
# It is also possible to compute and plot the power and thrust coefficient curves. Since it is not done in the sizing process, it has to be computed first. It also requires additional inputs so we won't be able to reuse the output file as is. Instead we will use one that has been prepared for this demonstration.

# %%
CONFIGURATION_FILE_DATA = pth.join(DATA_FOLDER_PATH, "propeller_coefficients.yml")
CONFIGURATION_FILE = pth.join(WORK_FOLDER_PATH, "propeller_coefficients.yml")

INPUT_FILE_PROP_DATA = pth.join(DATA_FOLDER_PATH, "propeller_coeff_inputs.xml")
INPUT_FILE_PROP = pth.join(WORK_FOLDER_PATH, "propeller_coeff_inputs.xml")

# First copy the configuration file and the input file inside the workfolder

shutil.copy(CONFIGURATION_FILE_DATA, CONFIGURATION_FILE)
shutil.copy(INPUT_FILE_PROP_DATA, INPUT_FILE_PROP)

eval_problem = oad.evaluate_problem(CONFIGURATION_FILE, overwrite=True)

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "propeller_coeff_outputs.xml")

fig = api_plots.propeller_coeff_map_plot(OUTPUT_FILE)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 3
#       1 OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "propeller_coeff_outputs.xml")
# ----> 3 fig = api_plots.propeller_coeff_map_plot(OUTPUT_FILE)
#       4 fig.show()
#
# AttributeError: module 'fastga.utils.postprocessing.post_processing_api' has no attribute 'propeller_coeff_map_plot'
